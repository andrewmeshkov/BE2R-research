# %% [markdown]
# # OpenVLA: An Open-Source Vision-Language-Action Model
# https://openvla.github.io/

# %% [markdown]
# # Large VLM-based Vision-Language-Action Models for Robotic Manipulation: A Survey
# https://arxiv.org/html/2508.13073v1

# %% [markdown]
# # LoLA: Long Horizon Latent Action Learning for General Robot Manipulation
# https://arxiv.org/pdf/2512.20166

# %% [markdown]
# # Long-VLA: Unleashing Long-Horizon Capability of Vision Language Action Model for Robot Manipulation
# https://arxiv.org/pdf/2508.19958

# %% [markdown]
# ## В следующих 2ух ноутбуках будут отсылки на статьи, которые указаны здесь. Я решил оставить 2 ноутбука, так как в процессе чтения статей и литературы у меня возникло 2 гипотезы и мне хотелось бы представить их обе
